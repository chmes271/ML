# %%
import numpy as np
import pandas as pd
from apyori import apriori
from mlxtend.frequent_patterns import apriori, association_rules

# %%
data = pd.read_csv(r'C:\Users\Vishal\Desktop\csv files\Groceries_dataset.csv')

# %%
data
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
data.itemDescription.value_counts()
# Out:
# whole milk               2502
# other vegetables         1898
# rolls/buns               1716
# soda                     1514
# yogurt                   1334
#                          ...
# rubbing alcohol             5
# bags                        4
# baby cosmetics              3
# kitchen utensil             1
# preservation products       1
# Name: itemDescription, Length: 167, dtype: int64

# %%
store = data.groupby(['Member_number', 'itemDescription'])['itemDescription'].count().unstack().fillna(0).applymap(lambda x :1 if x>0 else 0)

# %%
store.tail(4)
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 4997                                 0         0                 0
# 4998                                 0         0                 0
# 4999                                 0         0                 0
# 5000                                 0         0                 0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# 4997                            0               0     0              0
# 4998                            0               0     0              0
# 4999                            0               0     0              0
# 5000                            0               0     0              0
#
# itemDescription  bathroom cleaner  beef  berries  ...  turkey  vinegar  \
# Member_number                                     ...
# 4997                            0     0        0  ...       0        0
# ...

# %%
frequent_itemsets = apriori(store, min_support=0.02, use_colnames=True)

# %%
type(frequent_itemsets)
# Out:
# pandas.core.frame.DataFrame

# %%
frequent_itemsets.sort_values('support', ascending = False)
# Out:
#       support                                          itemsets
# 85   0.458184                                      (whole milk)
# 52   0.376603                                (other vegetables)
# 64   0.349666                                      (rolls/buns)
# 73   0.313494                                            (soda)
# 86   0.282966                                          (yogurt)
# ..        ...                                               ...
# 100  0.020010                                (beef, newspapers)
# 99   0.020010                               (beef, frankfurter)
# 265  0.020010                      (root vegetables, chocolate)
# 374  0.020010           (frozen vegetables, whipped/sour cream)
# 621  0.020010  (other vegetables, shopping bags, bottled water)
#
# [894 rows x 2 columns]

# %%
rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.5)
rules.sort_values("support", ascending=False).head(10)
# Out:
#            antecedents   consequents  antecedent support  consequent support  \
# 30  (other vegetables)  (whole milk)            0.376603            0.458184
# 36        (rolls/buns)  (whole milk)            0.349666            0.458184
# 45            (yogurt)  (whole milk)            0.282966            0.458184
# 3      (bottled water)  (whole milk)            0.213699            0.458184
# 37           (sausage)  (whole milk)            0.206003            0.458184
# 38     (shopping bags)  (whole milk)            0.168291            0.458184
# 31            (pastry)  (whole milk)            0.177527            0.458184
# 7        (canned beer)  (whole milk)            0.165213            0.458184
# 32         (pip fruit)  (whole milk)            0.170600            0.458184
# 2       (bottled beer)  (whole milk)            0.158799            0.458184
#
#      support  confidence      lift  leverage  conviction
# 30  0.191380    0.508174  1.109106  0.018827    1.101643
# ...

# %%
rules[rules['confidence']>0.6].count()
# Out:
# antecedents           286
# consequents           286
# antecedent support    286
# consequent support    286
# support               286
# confidence            286
# lift                  286
# leverage              286
# conviction            286
# dtype: int64

# %%
bins = [0.5, 0.55, 0.65, 0.8, 1.0]
rules['confidence'] = pd.cut(rules['confidence'], bins)

# %%
rules.groupby(rules['confidence'])['antecedents', 'consequents'].count()
# Out:
# C:\Users\Vishal\AppData\Local\Temp/ipykernel_12140/1576958093.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   rules.groupby(rules['confidence'])['antecedents', 'consequents'].count()
#               antecedents  consequents
# confidence
# (0.5, 0.55]           118          118
# (0.55, 0.65]          122          122
# (0.65, 0.8]             4            4
# (0.8, 1.0]              0            0
